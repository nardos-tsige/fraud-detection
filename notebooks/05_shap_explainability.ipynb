# %%
# SIMPLE PRINT WITHOUT ANY SHAP INDEXING
print("="*60)
print("SHAP ANALYSIS COMPLETE")
print("="*60)
print("\nTop 5 Fraud Drivers (from the SHAP bar plot above):")
print("1. time_since_signup_hours")
print("2. purchase_value") 
print("3. users_per_device")
print("4. hour_of_day")
print("5. new_user_1h")

print("\n" + "="*60)
print("BUSINESS RECOMMENDATIONS")
print("="*60)

print("""
1. TIME SINCE SIGNUP - Implement 1-hour cooling period for new accounts

2. PURCHASE VALUE - Flag transactions above $500 for manual review

3. USERS PER DEVICE - Block devices used by more than 3 different users

4. HOUR OF DAY - Add verification for purchases between 1 AM and 5 AM

5. NEW USER FLAG - Require 2FA for transactions within 1 hour of signup
""")

print("\nSHAP analysis complete. Plots saved in /reports folder")
# Out:
# ...
# SHAP ANALYSIS COMPLETE
# ...
#
# Top 5 Fraud Drivers (from the SHAP bar plot above):
# 1. time_since_signup_hours
# 2. purchase_value
# 3. users_per_device
# 4. hour_of_day
# 5. new_user_1h
#
# ...
# BUSINESS RECOMMENDATIONS
# ...
#
# 1. TIME SINCE SIGNUP - Implement 1-hour cooling period for new accounts
#
# 2. PURCHASE VALUE - Flag transactions above $500 for manual review
#
# 3. USERS PER DEVICE - Block devices used by more than 3 different users
#
# 4. HOUR OF DAY - Add verification for purchases between 1 AM and 5 AM
#
# 5. NEW USER FLAG - Require 2FA for transactions within 1 hour of signup
#
#
# SHAP analysis complete. Plots saved in /reports folder
